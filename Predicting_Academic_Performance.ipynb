# %% [markdown]
# <a href="https://colab.research.google.com/github/Arminsbss/Arminsbss/blob/main/Predicting_Academic_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-becdcaaf-d270-4511-9cbe-9f2df5cc6b85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-becdcaaf-d270-4511-9cbe-9f2df5cc6b85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset.xlsx to dataset.xlsx
# User uploaded file "dataset.xlsx" with length 115015 bytes

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()
uploaded
import pandas as pd
data=pd.read_excel('dataset.xlsx', index_col=0)  
data
# Out:
# ...
#                         F.S  ...  Gender
# Address                      ...
# Urban        Greater than 3  ...  Female
# Urban        Greater than 3  ...  Female
# Rural        Greater than 3  ...  Female
# Rural        Greater than 3  ...  Female
# Urban        Greater than 3  ...  Female
# ...                     ...  ...     ...
# Rural    Less or equal to 3  ...    Male
# Urban    Less or equal to 3  ...  Female
# Urban    Less or equal to 3  ...    Male
# Rural        Greater than 3  ...    Male
# Urban        Greater than 3  ...  Female
#
# [1203 rows x 22 columns]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
x = list(data['No of absences from class in a month'])
y = list(data['No of absences from class in a month'])
plt.figure(figsize=(10,10))
plt.style.use('seaborn')
plt.scatter(x,y,marker="*",s=100,edgecolors="black",c="yellow")
plt.title("Excel sheet to Scatter Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-1ba916023a1c> in <module>()
#       5 plt.figure(figsize=(10,10))
#       6 plt.style.use('seaborn')
# ----> 7 plt.scatter(x,y,marker="*",s=100,edgecolors="black",c="yellow")
#       8 plt.title("Excel sheet to Scatter Plot")
#       9 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
# ...
